# %%
import pandas as pd
df = pd.read_csv("./data/adult_income_dataset.csv")
# df.head()
# df.shape
# df.dtypes
# age_column = df['age']
# age_column.head()
# df[df['age'] >= 30]
# df.query('age >= 30')
# df_sorted = df.sort_values(by='age')
# df_sorted.head()
# df.isnull().sum()
# df_cleaned = df.dropna()
# df_cleaned.isnull().sum()
# mean_ages = df.groupby("sex")["age"].mean()
# mean_ages
# df["age"].plot(kind="hist")
mean_age = df["age"].mean()
median_age = df["age"].median()
std_age = df["age"].std()

print("平均値:", mean_age)
print("中央値:", median_age)
print("標準偏差:", std_age)
# Out:
# 平均値: 38.58164675532078
# 中央値: 37.0
# 標準偏差: 13.640432553581341

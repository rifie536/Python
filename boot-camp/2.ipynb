# %%
import pandas as pd
df = pd.read_csv("./data/adult_income_dataset.csv")
# df.head()
# df.shape
# df.dtypes
age_column = df['age']
age_column.head()
# Out:
# 0    39
# 1    50
# 2    38
# 3    53
# 4    28
# Name: age, dtype: int64
